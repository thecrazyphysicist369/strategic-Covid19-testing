# %% [markdown]
# <a href="https://colab.research.google.com/github/thecrazyphysicist369/strategic-Covid19-testing/blob/main/v2_Targeted_%2B_n_Neighbor_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Covid Lockdown Project
# This project tries to answer what is the effect of lockdown in a given population in a **Watts-Strogatz Small World Network**.
# Also is a lockdown at all necessary to curb the spread of the virus?

# %%
#Importing all the necessary libraries
import matplotlib.pyplot as plt
import networkx as nx
import random
import numpy as np
import time
import math
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# This is the new model which considers the amount and the order of infection. This also considers the parameters and virus spreading more like real world. The *Contamination Level* for each individual is the amount of virus they are exposed to.
#
# 1. 1 < *Cont_level* < 25 : Susceptible
# 2. 26 < *Cont_level* < 50 : Exposed
# 3. 51 < *Cont_level* < 75 : Infected
# 4. 76 < *Cont_level* : Recovered

# %%
#vertex generator generates each individual with their properties
def gen_vertex(n):
    ver_list=[]
    c=0

    for i in range(n):
      vertex = {
                'index': c, 			# the unique index of the voter
                'cont_level' : 0, # a positive number that increases everytime the
                                  #individual meets another with covid.
                'connected': []   # the small world connections between the individuals
                }
      ver_list.append(vertex)
      c+=1
    return ver_list

#Generating the Small World Network
def gen_graph(n, k, p):
   population = gen_vertex(n)
   G = nx.watts_strogatz_graph(n, k, p, seed=10)
   neighbor = []
   for node in list(sorted(G.nodes())):
   	neighbours = list(nx.all_neighbors(G, node))
   	neighbor.append(neighbours)
   for i in range(n):
     population[i]['connected'] = neighbor[i]
     population[i]['index'] = int(i)
     population[i]['cont_level'] = random.randint(0, 15)
   return population

#this is to expose n individuals from the population to the virus
#1/5th of the exposed individuals will be infected in random
def expose_population(n, population):
  inf_list = []
  limit = len(population)-1
  for i in range(n):
    index = random.randint(0, limit)
    inf_list.append(index)
    population[index]['cont_level'] = random.randint(25, 30) 
  return population, inf_list

#index testing
def contacts_testing(pop, index, n):
  if n>0:
    contacts = pop[index]['connected']
    for friends in contacts:
      if test(pop, friends)
        contacts_testing(pop, friends, n-1)


#just test
def test(pop, index):
  if pop[index]['cont_level'] <= 150 and pop[index]['cont_level'] > 25:
    #print(index, "found positive")
    pop[index]['cont_level'] = -10
    return True
  else:
    return False

#n neighbor testing
def n_neighbor_testing(pop, tpm, list_i, n): #pop = population; tpm = tests per million
  numbers = len(pop) # total population
  test = int((tpm * numbers)/1000000) # number of tests that is needed to be done
  test_i = (len(list_i) * test)/numbers
  for i in range(test):
    index = random.randint(0, len(list_i)-1)
    contacts_testing(pop, index, n)
  return pop
  

#Death function
def death(pop, infected):
  for i in range(random.randint(0, int(len(infected)/100))):
    index = infected[i]
    pop[index]['cont_level']=151
  return pop

#Recovery
def recovery(pop, infected):
  for i in range(random.randint(0, int(len(infected)/10))):
    index = infected[i]
    pop[index]['cont_level']=-10
  return pop



#Contamination function
def contaminate(a, b):
  if a > 0 and a <= 130:
    new = a + math.log10(b)
  else:
    new = a
  return new

def progress_bar(est, elas):
  perc=(elas/est)*10
  perc=int(perc)
  rem=10-perc
  print('[','#'*perc,' '*rem,']', ' ',perc*10, '%')

# %%
population = gen_graph(100,3,0.3)

# %% [markdown]
# #Run this cell

# %%
def days(pop, tpm):
  list_S = [] #list for Susceptible Individuals
  list_E = [] #list for Exposed Individuals
  list_I = [] #list for Infected Individuals
  list_R = [] #list for Recovered Individuals
  list_D = [] #list for Dead Individuals

  #Adding person to the respective lists based on their status
  #compartmening the population
  for person in pop:
    level = person['cont_level']
    if level >= 0 and level <= 25:
      list_S.append(person['index'])
    elif level > 25 and level <= 65:
      list_E.append(person['index'])
    elif level > 65 and level <=150:
      list_I.append(person['index'])
    elif level > 150:
      list_D.append(person['index'])
    elif level==-10:
      list_R.append(person['index'])


  #Infecting 1/5th of exposed population
  ex_num = len(list_E)
  num = int(ex_num/5)
  for i in range(num):
    r = random.randint(0,ex_num-1)
    list_I.append(list_E[r])
    list_E.pop(r)
    ex_num = len(list_E)


  #Spreading the Virus
  for i in list_I:
    friends = pop[i]['connected']  
    for contacts in friends:
      A = pop[contacts]['cont_level'] #is consuming
      B = pop[i]['cont_level'] #is spreading
      pop[contacts]['cont_level'] = contaminate(A, B)  #write a good fucntion here

  

  #Removing the duplicates from the list
  list_S = list(dict.fromkeys(list_S))
  list_E = list(dict.fromkeys(list_E))
  list_I = list(dict.fromkeys(list_I))
  list_R = list(dict.fromkeys(list_R))
  list_D = list(dict.fromkeys(list_D))

  #testing the population
  pop = n_neighbor_testing(pop, tpm, list_I, n)
  pop = recovery(pop, list_I)
  pop = death(pop, list_I)


  return (pop, list_S, list_E, list_I, list_R, list_D)

# %% [markdown]
# #Execute this if you want to run the simulation with input values.

# %%
population_size = 1000

k = 5 #int(input("\nk nearest neighbors : "))

p = 0.5 # float(input("\nProbablity of the contacts : "))

tpm = 10000 #int(input("\nTests per million population : "))

iterations = 1000 #int(input("\nNumber of days the model to run : "))

ex = 50 #int(input("\nNumber of Individuals initially exposed"))

n = 2
#Generating the small world network
population = gen_graph( population_size, k, p)

#Exposing the population
#li is the list of the first round of exposed population
population,li = expose_population(ex, population)


#Number of days the simulation need to run
count = np.arange(iterations)


# List to contain the current data
susp = []
expo = []
infe = []
reco = []
dead = []


elapsed = 0
# Running the days simulation for given number of days
for j in range (iterations):
	inter = []
	tic = time.time()
	population, sus, exp, inf, rec, ded = days(population, tpm)
	susp.append(len(sus)) #Count of suspected persons per day
	expo.append(len(exp)) #Count of exposed persons per day
	infe.append(len(inf)) #Count of infected persons per day
	reco.append(len(rec)) #Count of recovered persons per day
	dead.append(len(ded))
	toc = time.time()
	one_day = toc - tic
	elapsed += one_day  
	estimated = elapsed*(iterations-j)
	remaining = (iterations * one_day) - (j * one_day)
	#progress_bar(estimated, elapsed)
	print("Doing ",j,"th iteration. Time :","{:.2f}".format(one_day),
	      "secs. Elapsed time :","{:.2f}".format(elapsed),"secs. Estimated : ","{:.2f}".format(estimated),"secs")


plt.plot(count, susp, color='b', label = "Susceptible")
plt.plot(count, expo, color='y', label = "Exposed")
plt.plot(count, infe, color='r', label = "Infected")
plt.plot(count, reco, color='g', label = "Recovered")
plt.plot(count, dead, color='k', label = "Dead")
label = "Probability = "+str(p)+". Nearest Neigbours = "+str(k)+"."
plt.title(label, fontdict=None, loc='center', pad=None)
plt.legend()
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# 1 found positive
# 2 found positive
# 3 found positive
# 0 found positive
# 1 found positive
# Doing  545 th iteration. Time : 0.00 secs. Elapsed time : 2.74 secs. Estimated :  1244.67 secs
# 2 found positive
# 4 found positive
# 6 found positive
# 5 found positive
# 1 found positive
# 8 found positive
# 4 found positive
# 6 found positive
# 0 found positive
# 1 found positive
# Doing  546 th iteration. Time : 0.00 secs. Elapsed time : 2.74 secs. Estimated :  1242.43 secs
# 7 found positive
# 2 found positive
# 6 found positive
# 0 found positive
# 3 found positive
# 6 found positive
# 1 found positive
# 8 found positive
# 7 found positive
# 0 found positive
# Doing  547 th iteration. Time : 0.00 secs. Elapsed time : 2.74 secs. Estimated :  1240.20 secs
# 3 found positive
# 2 found positive
# 2 found positive
# 1 found positive
# 3 found positive
# 8 found positive
# 7 found positive
# 0 found positive
# 8 found positive
# 7 found positive
# Doing  548 th iteration. Time : 0.01 secs. Elapsed time : 2.75 secs. Estimated :  1240.88 secs
# 7 found positive
# 0 found positive
# 3 found positive
# 3 found positive
# 7 found positive
# 4 found positive
# 3 found positive
# 0 found positive
# 8 found positive
# 7 found positive
# Doing  549 th iteration. Time : 0.01 secs. Elapsed time : 2.75 secs. Estimated :  1242.00 secs
# 1 found positive
# 3 found positive
# 7 found positive
# 6 found positive
# 8 found positive
# 7 found positive
# 0 found positive
# 5 found positive
# 4 found positive
# 1 found positive
# Doing  550 th iteration. Time : 0.00 secs. Elapsed time : 2.76 secs. Estimated :  1240.43 secs
# 1 found positive
# 5 found positive
# 7 found positive
# 5 found positive
# 3 found positive
# 3 found positive
# 5 found positive
# 0 found positive
# 4 found positive
# 5 found positive
# Doing  551 th iteration. Time : 0.00 secs. Elapsed time : 2.76 secs. Estimated :  1238.36 secs
# 2 found positive
# 1 found positive
# 3 found positive
# 0 found positive
# 5 found positive
# 0 found positive
# 4 found positive
# 8 found positive
# 8 found positive
# 2 found positive
# Doing  552 th iteration. Time : 0.00 secs. Elapsed time : 2.76 secs. Estimated :  1236.06 secs
# 0 found positive
# 5 found positive
# 2 found positive
# 6 found positive
# 2 found positive
# 4 found positive
# 8 found positive
# 4 found positive
# 1 found positive
# 4 found positive
# Doing  553 th iteration. Time : 0.00 secs. Elapsed time : 2.76 secs. Estimated :  1234.59 secs
# 7 found positive
# 3 found positive
# 0 found positive
# 4 found positive
# 6 found positive
# 4 found positive
# 7 found positive
# 0 found positive
# 6 found positive
# 3 found positive
# Doing  554 th iteration. Time : 0.00 secs. Elapsed time : 2.76 secs. Estimated :  1232.25 secs
# 6 found positive
# 4 found positive
# 5 found positive
# 1 found positive
# 2 found positive
# 4 found positive
# 5 found positive
# 3 found positive
# 1 found positive
# 3 found positive
# Doing  555 th iteration. Time : 0.00 secs. Elapsed time : 2.76 secs. Estimated :  1229.91 secs
# 8 found positive
# 2 found positive
# 3 found positive
# 1 found positive
# 0 found positive
# 5 found positive
# 8 found positive
# 8 found positive
# 6 found positive
# 3 found positive
# Doing  556 th iteration. Time : 0.01 secs. Elapsed time : 2.77 secs. Estimated :  1231.10 secs
# 2 found positive
# 7 found positive
# 0 found positive
# 2 found positive
# 7 found positive
# 0 found positive
# 1 found positive
# 2 found positive
# 4 found positive
# 5 found positive
# Doing  557 th iteration. Time : 0.00 secs. Elapsed time : 2.77 secs. Estimated :  1228.81 secs
# 2 found positive
# 4 found positive
# 1 found positive
# 8 found positive
# 0 found positive
# 8 found positive
# 5 found positive
# 8 found positive
# 1 found positive
# 2 found positive
# Doing  558 th iteration. Time : 0.01 secs. Elapsed time : 2.78 secs. Estimated :  1228.42 secs
# 4 found positive
# 7 found positive
# 2 found positive
# 4 found positive
# 5 found positive
# 4 found positive
# 3 found positive
# 5 found positive
# 4 found positive
# 6 found positive
# Doing  559 th iteration. Time : 0.00 secs. Elapsed time : 2.78 secs. Estimated :  1226.11 secs
# 2 found positive
# 4 found positive
# 1 found positive
# 6 found positive
# 4 found positive
# 4 found positive
# 6 found positive
# 8 found positive
# 0 found positive
# 5 found positive
# Doing  560 th iteration. Time : 0.00 secs. Elapsed time : 2.78 secs. Estimated :  1224.60 secs
# 5 found positive
# 8 found positive
# 0 found positive
# 7 found positive
# 0 found positive
# 4 found positive
# 7 found positive
# 6 found positive
# 4 found positive
# 2 found positive
# Doing  561 th iteration. Time : 0.00 secs. Elapsed time : 2.79 secs. Estimated :  1223.91 secs
# 8 found positive
# 8 found positive
# 4 found positive
# 8 found positive
# 8 found positive
# 8 found positive
# 0 found positive
# 3 found positive
# 4 found positive
# 1 found positive
# Doing  562 th iteration. Time : 0.00 secs. Elapsed time : 2.79 secs. Estimated :  1222.04 secs
# 2 found positive
# 7 found positive
# 6 found positive
# 6 found positive
# 2 found positive
# 6 found positive
# 0 found positive
# 5 found positive
# 3 found positive
# 7 found positive
# Doing  563 th iteration. Time : 0.00 secs. Elapsed time : 2.79 secs. Estimated :  1219.67 secs
# 7 found positive
# 8 found positive
# 0 found positive
# 0 found positive
# 7 found positive
# 1 found positive
# 3 found positive
# 6 found positive
# 8 found positive
# 5 found positive
# Doing  564 th iteration. Time : 0.01 secs. Elapsed time : 2.80 secs. Estimated :  1220.90 secs
# 5 found positive
# 3 found positive
# 8 found positive
# 4 found positive
# 1 found positive
# 3 found positive
# 8 found positive
# 5 found positive
# 8 found positive
# 8 found positive
# Doing  565 th iteration. Time : 0.00 secs. Elapsed time : 2.80 secs. Estimated :  1218.73 secs
# 7 found positive
# 0 found positive
# 8 found positive
# 7 found positive
# 5 found positive
# 2 found positive
# 6 found positive
# 4 found positive
# 8 found positive
# 4 found positive
# Doing  566 th iteration. Time : 0.00 secs. Elapsed time : 2.80 secs. Estimated :  1216.33 secs
# 3 found positive
# 3 found positive
# 7 found positive
# 4 found positive
# 1 found positive
# 4 found positive
# 1 found positive
# 4 found positive
# 0 found positive
# 5 found positive
# Doing  567 th iteration. Time : 0.04 secs. Elapsed time : 2.85 secs. Estimated :  1231.95 secs
# 2 found positive
# 3 found positive
# 6 found positive
# 6 found positive
# 6 found positive
# 8 found positive
# 7 found positive
# 6 found positive
# 4 found positive
# 1 found positive
# Doing  568 th iteration. Time : 0.00 secs. Elapsed time : 2.85 secs. Estimated :  1229.46 secs
# 3 found positive
# 4 found positive
# 7 found positive
# 2 found positive
# 8 found positive
# 8 found positive
# 6 found positive
# 5 found positive
# 6 found positive
# 0 found positive
# Doing  569 th iteration. Time : 0.00 secs. Elapsed time : 2.85 secs. Estimated :  1226.87 secs
# 8 found positive
# 1 found positive
# 5 found positive
# 6 found positive
# 5 found positive
# 1 found positive
# 1 found positive
# 2 found positive
# 0 found positive
# 3 found positive
# Doing  570 th iteration. Time : 0.01 secs. Elapsed time : 2.85 secs. Estimated :  1226.20 secs
# 8 found positive
# 7 found positive
# 6 found positive
# 0 found positive
# 2 found positive
# 1 found positive
# 0 found positive
# 2 found positive
# 0 found positive
# 3 found positive
# Doing  571 th iteration. Time : 0.01 secs. Elapsed time : 2.86 secs. Estimated :  1225.77 secs
# 4 found positive
# 6 found positive
# 7 found positive
# 2 found positive
# 4 found positive
# 0 found positive
# 0 found positive
# 4 found positive
# 6 found positive
# 1 found positive
# Doing  572 th iteration. Time : 0.00 secs. Elapsed time : 2.86 secs. Estimated :  1224.63 secs
# 8 found positive
# 6 found positive
# 4 found positive
# 0 found positive
# 8 found positive
# 1 found positive
# 8 found positive
# 8 found positive
# 1 found positive
# 4 found positive
# Doing  573 th iteration. Time : 0.00 secs. Elapsed time : 2.86 secs. Estimated :  1222.20 secs
# 3 found positive
# 3 found positive
# 0 found positive
# 3 found positive
# 0 found positive
# 7 found positive
# 5 found positive
# 6 found positive
# 7 found positive
# 1 found positive
# Doing  574 th iteration. Time : 0.01 secs. Elapsed time : 2.87 secs. Estimated :  1223.94 secs
# 5 found positive
# 8 found positive
# 0 found positive
# 6 found positive
# 8 found positive
# 3 found positive
# 8 found positive
# 6 found positive
# 3 found positive
# 6 found positive
# Doing  575 th iteration. Time : 0.00 secs. Elapsed time : 2.88 secs. Estimated :  1222.58 secs
# 1 found positive
# 8 found positive
# 6 found positive
# 6 found positive
# 3 found positive
# 0 found positive
# 5 found positive
# 4 found positive
# 1 found positive
# 4 found positive
# Doing  576 th iteration. Time : 0.01 secs. Elapsed time : 2.88 secs. Estimated :  1221.84 secs
# 1 found positive
# 2 found positive
# 8 found positive
# 8 found positive
# 2 found positive
# 6 found positive
# 1 found positive
# 1 found positive
# 0 found positive
# 7 found positive
# Doing  577 th iteration. Time : 0.00 secs. Elapsed time : 2.88 secs. Estimated :  1219.43 secs
# 3 found positive
# 3 found positive
# 6 found positive
# 0 found positive
# 2 found positive
# 0 found positive
# 5 found positive
# 0 found positive
# 2 found positive
# 7 found positive
# Doing  578 th iteration. Time : 0.00 secs. Elapsed time : 2.88 secs. Estimated :  1217.11 secs
# 6 found positive
# 6 found positive
# 0 found positive
# 8 found positive
# 6 found positive
# 3 found positive
# 8 found positive
# 2 found positive
# 4 found positive
# 8 found positive
# Doing  579 th iteration. Time : 0.00 secs. Elapsed time : 2.89 secs. Estimated :  1214.66 secs
# 6 found positive
# 2 found positive
# 3 found positive
# 8 found positive
# 0 found positive
# 8 found positive
# 0 found positive
# 2 found positive
# 0 found positive
# 7 found positive
# Doing  580 th iteration. Time : 0.00 secs. Elapsed time : 2.89 secs. Estimated :  1212.24 secs
# 7 found positive
# 5 found positive
# 6 found positive
# 3 found positive
# 0 found positive
# 8 found positive
# 1 found positive
# 2 found positive
# 6 found positive
# 7 found positive
# Doing  581 th iteration. Time : 0.00 secs. Elapsed time : 2.89 secs. Estimated :  1210.03 secs
# 8 found positive
# 5 found positive
# 1 found positive
# 7 found positive
# 3 found positive
# 3 found positive
# 3 found positive
# 2 found positive
# 1 found positive
# 3 found positive
# Doing  582 th iteration. Time : 0.00 secs. Elapsed time : 2.89 secs. Estimated :  1207.68 secs
# 6 found positive
# 6 found positive
# 6 found positive
# 2 found positive
# 5 found positive
# 2 found positive
# 0 found positive
# 7 found positive
# 3 found positive
# 4 found positive
# Doing  583 th iteration. Time : 0.00 secs. Elapsed time : 2.89 secs. Estimated :  1205.28 secs
# 5 found positive
# 1 found positive
# 1 found positive
# 5 found positive
# 3 found positive
# 5 found positive
# 3 found positive
# 6 found positive
# 2 found positive
# 6 found positive
# Doing  584 th iteration. Time : 0.05 secs. Elapsed time : 2.94 secs. Estimated :  1223.37 secs
# 0 found positive
# 8 found positive
# 7 found positive
# 3 found positive
# 6 found positive
# 5 found positive
# 3 found positive
# 7 found positive
# 8 found positive
# 3 found positive
# Doing  585 th iteration. Time : 0.00 secs. Elapsed time : 2.94 secs. Estimated :  1220.89 secs
# 8 found positive
# 7 found positive
# 3 found positive
# 8 found positive
# 0 found positive
# 2 found positive
# 0 found positive
# 8 found positive
# 2 found positive
# 7 found positive
# Doing  586 th iteration. Time : 0.00 secs. Elapsed time : 2.94 secs. Estimated :  1218.41 secs
# 4 found positive
# 2 found positive
# 7 found positive
# 5 found positive
# 1 found positive
# 2 found positive
# 1 found positive
# 6 found positive
# 7 found positive
# 5 found positive
# Doing  587 th iteration. Time : 0.00 secs. Elapsed time : 2.95 secs. Estimated :  1217.40 secs
# 8 found positive
# 0 found positive
# 1 found positive
# 1 found positive
# 8 found positive
# 5 found positive
# 3 found positive
# 2 found positive
# 2 found positive
# 5 found positive
# Doing  588 th iteration. Time : 0.00 secs. Elapsed time : 2.95 secs. Estimated :  1214.96 secs
# 4 found positive
# 6 found positive
# 1 found positive
# 0 found positive
# 5 found positive
# 6 found positive
# 0 found positive
# 8 found positive
# 7 found positive
# 2 found positive
# Doing  589 th iteration. Time : 0.00 secs. Elapsed time : 2.95 secs. Estimated :  1212.40 secs
# 6 found positive
# 0 found positive
# 4 found positive
# 3 found positive
# 1 found positive
# 1 found positive
# 0 found positive
# 6 found positive
# 3 found positive
# 5 found positive
# Doing  590 th iteration. Time : 0.02 secs. Elapsed time : 2.97 secs. Estimated :  1216.21 secs
# 5 found positive
# 7 found positive
# 6 found positive
# 7 found positive
# 0 found positive
# 8 found positive
# 7 found positive
# 4 found positive
# 6 found positive
# 1 found positive
# Doing  591 th iteration. Time : 0.00 secs. Elapsed time : 2.97 secs. Estimated :  1213.83 secs
# 8 found positive
# 6 found positive
# 7 found positive
# 2 found positive
# 0 found positive
# 5 found positive
# 2 found positive
# 6 found positive
# 2 found positive
# 3 found positive
# Doing  592 th iteration. Time : 0.00 secs. Elapsed time : 2.97 secs. Estimated :  1211.25 secs
# 8 found positive
# 3 found positive
# 5 found positive
# 3 found positive
# 0 found positive
# 6 found positive
# 8 found positive
# 6 found positive
# 4 found positive
# 1 found positive
# Doing  593 th iteration. Time : 0.00 secs. Elapsed time : 2.97 secs. Estimated :  1208.67 secs
# 8 found positive
# 3 found positive
# 3 found positive
# 5 found positive
# 2 found positive
# 7 found positive
# 3 found positive
# 5 found positive
# 5 found positive
# 7 found positive
# Doing  594 th iteration. Time : 0.00 secs. Elapsed time : 2.97 secs. Estimated :  1206.08 secs
# 6 found positive
# 0 found positive
# 6 found positive
# 7 found positive
# 5 found positive
# 8 found positive
# 5 found positive
# 0 found positive
# 7 found positive
# 3 found positive
# Doing  595 th iteration. Time : 0.00 secs. Elapsed time : 2.97 secs. Estimated :  1203.84 secs
# 1 found positive
# 8 found positive
# 2 found positive
# 3 found positive
# 5 found positive
# 6 found positive
# 8 found positive
# 4 found positive
# 2 found positive
# 6 found positive
# Doing  596 th iteration. Time : 0.00 secs. Elapsed time : 2.98 secs. Estimated :  1202.85 secs
# 6 found positive
# 5 found positive
# 0 found positive
# 5 found positive
# 6 found positive
# 5 found positive
# 7 found positive
# 0 found positive
# 7 found positive
# 1 found positive
# Doing  597 th iteration. Time : 0.00 secs. Elapsed time : 2.98 secs. Estimated :  1200.24 secs
# 5 found positive
# 3 found positive
# 2 found positive
# 4 found positive
# 7 found positive
# 8 found positive
# 0 found positive
# 0 found positive
# 2 found positive
# 2 found positive
# Doing  598 th iteration. Time : 0.00 secs. Elapsed time : 2.98 secs. Estimated :  1197.62 secs
# 7 found positive
# 0 found positive
# 1 found positive
# 1 found positive
# 0 found positive
# 8 found positive
# 8 found positive
# 3 found positive
# 0 found positive
# 4 found positive
# Doing  599 th iteration. Time : 0.01 secs. Elapsed time : 2.98 secs. Estimated :  1196.71 secs
# 3 found positive
# 2 found positive
# 4 found positive
# 3 found positive
# 0 found positive
# 4 found positive
# 7 found positive
# 5 found positive
# 5 found positive
# 6 found positive
# Doing  600 th iteration. Time : 0.00 secs. Elapsed time : 2.99 secs. Estimated :  1194.10 secs
# 6 found positive
# 5 found positive
# 3 found positive
# 5 found positive
# 4 found positive
# 7 found positive
# 5 found positive
# 6 found positive
# 7 found positive
# 6 found positive
# Doing  601 th iteration. Time : 0.05 secs. Elapsed time : 3.03 secs. Estimated :  1210.91 secs
# 1 found positive
# 7 found positive
# 7 found positive
# 7 found positive
# 5 found positive
# 1 found positive
# 4 found positive
# 4 found positive
# 0 found positive
# 0 found positive
# Doing  602 th iteration. Time : 0.01 secs. Elapsed time : 3.04 secs. Estimated :  1211.67 secs
# 3 found positive
# 4 found positive
# 0 found positive
# 3 found positive
# 8 found positive
# 8 found positive
# 7 found positive
# 6 found positive
# 3 found positive
# 7 found positive
# Doing  603 th iteration. Time : 0.00 secs. Elapsed time : 3.05 secs. Estimated :  1209.07 secs
# 6 found positive
# 2 found positive
# 0 found positive
# 3 found positive
# 4 found positive
# 6 found positive
# 4 found positive
# 8 found positive
# 5 found positive
# 4 found positive
# Doing  604 th iteration. Time : 0.00 secs. Elapsed time : 3.05 secs. Estimated :  1206.47 secs
# 1 found positive
# 6 found positive
# 1 found positive
# 0 found positive
# 6 found positive
# 3 found positive
# 4 found positive
# 3 found positive
# 7 found positive
# 4 found positive
# Doing  605 th iteration. Time : 0.00 secs. Elapsed time : 3.05 secs. Estimated :  1203.84 secs
# 7 found positive
# 3 found positive
# 5 found positive
# 5 found positive
# 0 found positive
# 4 found positive
# 1 found positive
# 5 found positive
# 7 found positive
# 7 found positive
# Doing  606 th iteration. Time : 0.00 secs. Elapsed time : 3.05 secs. Estimated :  1201.78 secs
# 5 found positive
# 3 found positive
# 1 found positive
# 2 found positive
# 6 found positive
# 8 found positive
# 8 found positive
# 5 found positive
# 1 found positive
# 2 found positive
# Doing  607 th iteration. Time : 0.00 secs. Elapsed time : 3.05 secs. Estimated :  1200.08 secs
# 6 found positive
# 4 found positive
# 4 found positive
# 0 found positive
# 8 found positive
# 8 found positive
# 8 found positive
# 5 found positive
# 4 found positive
# 4 found positive
# Doing  608 th iteration. Time : 0.00 secs. Elapsed time : 3.05 secs. Estimated :  1197.43 secs
# 6 found positive
# 6 found positive
# 7 found positive
# 5 found positive
# 0 found positive
# 0 found positive
# 4 found positive
# 5 found positive
# 1 found positive
# 3 found positive
# Doing  609 th iteration. Time : 0.00 secs. Elapsed time : 3.06 secs. Estimated :  1194.76 secs
# 3 found positive
# 2 found positive
# 4 found positive
# 5 found positive
# 6 found positive
# 2 found positive
# 7 found positive
# 3 found positive
# 6 found positive
# 2 found positive
# Doing  610 th iteration. Time : 0.00 secs. Elapsed time : 3.06 secs. Estimated :  1192.06 secs
# 2 found positive
# 8 found positive
# 5 found positive
# 3 found positive
# 2 found positive
# 5 found positive
# 0 found positive
# 1 found positive
# 8 found positive
# 6 found positive
# Doing  611 th iteration. Time : 0.00 secs. Elapsed time : 3.06 secs. Estimated :  1189.44 secs
# 5 found positive
# 0 found positive
# 2 found positive
# 4 found positive
# 0 found positive
# 5 found positive
# 6 found positive
# 7 found positive
# 6 found positive
# 7 found positive
# Doing  612 th iteration. Time : 0.00 secs. Elapsed time : 3.06 secs. Estimated :  1186.78 secs
# 7 found positive
# 3 found positive
# 1 found positive
# 3 found positive
# 1 found positive
# 7 found positive
# 5 found positive
# 4 found positive
# 5 found positive
# 2 found positive
# Doing  613 th iteration. Time : 0.00 secs. Elapsed time : 3.06 secs. Estimated :  1184.13 secs
# 1 found positive
# 3 found positive
# 8 found positive
# 4 found positive
# 6 found positive
# 2 found positive
# 2 found positive
# 5 found positive
# 4 found positive
# 8 found positive
# Doing  614 th iteration. Time : 0.00 secs. Elapsed time : 3.06 secs. Estimated :  1181.35 secs
# 7 found positive
# 3 found positive
# 5 found positive
# 1 found positive
# 3 found positive
# 6 found positive
# 1 found positive
# 1 found positive
# 1 found positive
# 4 found positive
# Doing  615 th iteration. Time : 0.02 secs. Elapsed time : 3.08 secs. Estimated :  1184.77 secs
# 1 found positive
# 1 found positive
# 2 found positive
# 5 found positive
# 7 found positive
# 2 found positive
# 3 found positive
# 1 found positive
# 8 found positive
# 0 found positive
# Doing  616 th iteration. Time : 0.02 secs. Elapsed time : 3.09 secs. Estimated :  1187.47 secs
# 5 found positive
# 2 found positive
# 0 found positive
# 7 found positive
# 0 found positive
# 1 found positive
# 4 found positive
# 3 found positive
# 5 found positive
# 4 found positive
# Doing  617 th iteration. Time : 0.02 secs. Elapsed time : 3.11 secs. Estimated :  1191.07 secs
# 6 found positive
# 7 found positive
# 3 found positive
# 4 found positive
# 3 found positive
# 0 found positive
# 6 found positive
# 3 found positive
# 4 found positive
# 2 found positive
# Doing  618 th iteration. Time : 0.01 secs. Elapsed time : 3.12 secs. Estimated :  1192.34 secs
# 8 found positive
# 7 found positive
# 8 found positive
# 3 found positive
# 4 found positive
# 5 found positive
# 7 found positive
# 3 found positive
# 7 found positive
# 6 found positive
# Doing  619 th iteration. Time : 0.01 secs. Elapsed time : 3.13 secs. Estimated :  1193.37 secs
# 7 found positive
# 5 found positive
# 8 found positive
# 0 found positive
# 1 found positive
# 7 found positive
# 2 found positive
# 5 found positive
# 4 found positive
# 5 found positive
# Doing  620 th iteration. Time : 0.00 secs. Elapsed time : 3.14 secs. Estimated :  1191.72 secs
# 0 found positive
# 6 found positive
# 1 found positive
# 8 found positive
# 2 found positive
# 4 found positive
# 5 found positive
# 0 found positive
# 5 found positive
# 2 found positive
# Doing  621 th iteration. Time : 0.00 secs. Elapsed time : 3.14 secs. Estimated :  1188.98 secs
# 4 found positive
# 8 found positive
# 1 found positive
# 7 found positive
# 1 found positive
# 3 found positive
# 2 found positive
# 3 found positive
# 6 found positive
# 5 found positive
# Doing  622 th iteration. Time : 0.00 secs. Elapsed time : 3.14 secs. Estimated :  1186.35 secs
# 8 found positive
# 3 found positive
# 8 found positive
# 7 found positive
# 5 found positive
# 7 found positive
# 5 found positive
# 4 found positive
# 6 found positive
# 5 found positive
# Doing  623 th iteration. Time : 0.00 secs. Elapsed time : 3.14 secs. Estimated :  1183.60 secs
# 5 found positive
# 8 found positive
# 7 found positive
# 0 found positive
# 8 found positive
# 8 found positive
# 1 found positive
# 4 found positive
# 7 found positive
# 0 found positive
# Doing  624 th iteration. Time : 0.01 secs. Elapsed time : 3.15 secs. Estimated :  1184.43 secs
# 0 found positive
# 6 found positive
# 7 found positive
# 2 found positive
# 7 found positive
# 5 found positive
# 0 found positive
# 1 found positive
# 5 found positive
# 1 found positive
# Doing  625 th iteration. Time : 0.00 secs. Elapsed time : 3.15 secs. Estimated :  1181.65 secs
# 1 found positive
# 5 found positive
# 6 found positive
# 1 found positive
# 6 found positive
# 6 found positive
# 1 found positive
# 6 found positive
# 7 found positive
# 7 found positive
# Doing  626 th iteration. Time : 0.00 secs. Elapsed time : 3.15 secs. Estimated :  1178.84 secs
# 0 found positive
# 3 found positive
# 1 found positive
# 0 found positive
# 2 found positive
# 6 found positive
# 4 found positive
# 4 found positive
# 1 found positive
# 0 found positive
# Doing  627 th iteration. Time : 0.01 secs. Elapsed time : 3.16 secs. Estimated :  1177.90 secs
# 6 found positive
# 6 found positive
# 7 found positive
# 6 found positive
# 6 found positive
# 6 found positive
# 5 found positive
# 6 found positive
# 5 found positive
# 5 found positive
# Doing  628 th iteration. Time : 0.00 secs. Elapsed time : 3.16 secs. Estimated :  1175.08 secs
# 4 found positive
# 8 found positive
# 5 found positive
# 7 found positive
# 7 found positive
# 2 found positive
# 4 found positive
# 4 found positive
# 7 found positive
# 3 found positive
# Doing  629 th iteration. Time : 0.01 secs. Elapsed time : 3.17 secs. Estimated :  1174.40 secs
# 5 found positive
# 2 found positive
# 6 found positive
# 0 found positive
# 2 found positive
# 3 found positive
# 0 found positive
# 6 found positive
# 2 found positive
# 0 found positive
# Doing  630 th iteration. Time : 0.00 secs. Elapsed time : 3.17 secs. Estimated :  1171.60 secs
# 1 found positive
# 0 found positive
# 0 found positive
# 2 found positive
# 3 found positive
# 3 found positive
# 8 found positive
# 7 found positive
# 5 found positive
# 3 found positive
# Doing  631 th iteration. Time : 0.00 secs. Elapsed time : 3.17 secs. Estimated :  1168.76 secs
# 8 found positive
# 1 found positive
# 5 found positive
# 6 found positive
# 6 found positive
# 6 found positive
# 8 found positive
# 6 found positive
# 7 found positive
# 6 found positive
# Doing  632 th iteration. Time : 0.01 secs. Elapsed time : 3.17 secs. Estimated :  1167.83 secs
# 0 found positive
# 0 found positive
# 7 found positive
# 6 found positive
# 4 found positive
# 8 found positive
# 7 found positive
# 4 found positive
# 3 found positive
# 4 found positive
# Doing  633 th iteration. Time : 0.00 secs. Elapsed time : 3.17 secs. Estimated :  1165.09 secs
# 3 found positive
# 0 found positive
# 1 found positive
# 0 found positive
# 5 found positive
# 7 found positive
# 8 found positive
# 7 found positive
# 0 found positive
# 6 found positive
# Doing  634 th iteration. Time : 0.00 secs. Elapsed time : 3.18 secs. Estimated :  1162.12 secs
# 5 found positive
# 6 found positive
# 8 found positive
# 5 found positive
# 6 found positive
# 8 found positive
# 4 found positive
# 7 found positive
# 2 found positive
# 7 found positive
# Doing  635 th iteration. Time : 0.02 secs. Elapsed time : 3.20 secs. Estimated :  1166.47 secs
# 6 found positive
# 8 found positive
# 1 found positive
# 4 found positive
# 4 found positive
# 5 found positive
# 6 found positive
# 7 found positive
# 4 found positive
# 0 found positive
# Doing  636 th iteration. Time : 0.03 secs. Elapsed time : 3.22 secs. Estimated :  1173.41 secs
# 5 found positive
# 0 found positive
# 7 found positive
# 1 found positive
# 3 found positive
# 4 found positive
# 8 found positive
# 4 found positive
# 4 found positive
# 0 found positive
# Doing  637 th iteration. Time : 0.00 secs. Elapsed time : 3.22 secs. Estimated :  1170.66 secs
# 3 found positive
# 2 found positive
# 2 found positive
# 7 found positive
# 0 found positive
# 4 found positive
# 2 found positive
# 7 found positive
# 2 found positive
# 0 found positive
# Doing  638 th iteration. Time : 0.00 secs. Elapsed time : 3.23 secs. Estimated :  1167.81 secs
# 7 found positive
# 5 found positive
# 3 found positive
# 0 found positive
# 8 found positive
# 1 found positive
# 1 found positive
# 0 found positive
# 5 found positive
# 3 found positive
# Doing  639 th iteration. Time : 0.01 secs. Elapsed time : 3.23 secs. Estimated :  1166.74 secs
# 4 found positive
# 7 found positive
# 8 found positive
# 1 found positive
# 4 found positive
# 4 found positive
# 4 found positive
# 8 found positive
# 2 found positive
# 4 found positive
# Doing  640 th iteration. Time : 0.00 secs. Elapsed time : 3.23 secs. Estimated :  1163.90 secs
# 3 found positive
# 6 found positive
# 8 found positive
# 2 found positive
# 1 found positive
# 4 found positive
# 7 found positive
# 5 found positive
# 6 found positive
# 1 found positive
# Doing  641 th iteration. Time : 0.00 secs. Elapsed time : 3.24 secs. Estimated :  1161.99 secs
# 5 found positive
# 2 found positive
# 6 found positive
# 8 found positive
# 2 found positive
# 7 found positive
# 2 found positive
# 6 found positive
# 1 found positive
# 2 found positive
# Doing  642 th iteration. Time : 0.01 secs. Elapsed time : 3.24 secs. Estimated :  1160.84 secs
# 8 found positive
# 8 found positive
# 7 found positive
# 8 found positive
# 6 found positive
# 5 found positive
# 0 found positive
# 2 found positive
# 1 found positive
# 7 found positive
# Doing  643 th iteration. Time : 0.02 secs. Elapsed time : 3.26 secs. Estimated :  1162.96 secs
# 2 found positive
# 1 found positive
# 3 found positive
# 4 found positive
# 8 found positive
# 2 found positive
# 8 found positive
# 4 found positive
# 3 found positive
# 6 found positive
# Doing  644 th iteration. Time : 0.01 secs. Elapsed time : 3.26 secs. Estimated :  1161.65 secs
# 7 found positive
# 1 found positive
# 5 found positive
# 3 found positive
# 7 found positive
# 5 found positive
# 7 found positive
# 5 found positive
# 6 found positive
# 4 found positive
# Doing  645 th iteration. Time : 0.00 secs. Elapsed time : 3.26 secs. Estimated :  1158.71 secs
# 6 found positive
# 4 found positive
# 0 found positive
# 8 found positive
# 0 found positive
# 4 found positive
# 8 found positive
# 6 found positive
# 0 found positive
# 2 found positive
# Doing  646 th iteration. Time : 0.00 secs. Elapsed time : 3.26 secs. Estimated :  1155.79 secs
# 8 found positive
# 6 found positive
# 8 found positive
# 0 found positive
# 2 found positive
# 8 found positive
# 8 found positive
# 5 found positive
# 3 found positive
# 7 found positive
# Doing  647 th iteration. Time : 0.00 secs. Elapsed time : 3.27 secs. Estimated :  1152.85 secs
# 0 found positive
# 7 found positive
# 8 found positive
# 8 found positive
# 1 found positive
# 3 found positive
# 7 found positive
# 3 found positive
# 5 found positive
# 2 found positive
# Doing  648 th iteration. Time : 0.00 secs. Elapsed time : 3.27 secs. Estimated :  1149.94 secs
# 4 found positive
# 2 found positive
# 1 found positive
# 0 found positive
# 0 found positive
# 0 found positive
# 5 found positive
# 0 found positive
# 5 found positive
# 6 found positive
# Doing  649 th iteration. Time : 0.00 secs. Elapsed time : 3.27 secs. Estimated :  1146.99 secs
# 8 found positive
# 3 found positive
# 3 found positive
# 5 found positive
# 0 found positive
# 2 found positive
# 4 found positive
# 2 found positive
# 4 found positive
# 4 found positive
# Doing  650 th iteration. Time : 0.00 secs. Elapsed time : 3.27 secs. Estimated :  1144.09 secs
# 0 found positive
# 7 found positive
# 0 found positive
# 7 found positive
# 2 found positive
# 3 found positive
# 8 found positive
# 2 found positive
# 6 found positive
# 0 found positive
# Doing  651 th iteration. Time : 0.00 secs. Elapsed time : 3.27 secs. Estimated :  1141.15 secs
# 3 found positive
# 1 found positive
# 7 found positive
# 1 found positive
# 1 found positive
# 6 found positive
# 4 found positive
# 5 found positive
# 0 found positive
# 3 found positive
# Doing  652 th iteration. Time : 0.00 secs. Elapsed time : 3.27 secs. Estimated :  1138.19 secs
# 0 found positive
# 5 found positive
# 8 found positive
# 4 found positive
# 8 found positive
# 1 found positive
# 4 found positive
# 0 found positive
# 3 found positive
# 3 found positive
# Doing  653 th iteration. Time : 0.03 secs. Elapsed time : 3.30 secs. Estimated :  1146.54 secs
# 0 found positive
# 4 found positive
# 2 found positive
# 0 found positive
# 1 found positive
# 3 found positive
# 3 found positive
# 1 found positive
# 5 found positive
# 8 found positive
# Doing  654 th iteration. Time : 0.00 secs. Elapsed time : 3.31 secs. Estimated :  1143.64 secs
# 8 found positive
# 0 found positive
# 5 found positive
# 8 found positive
# 8 found positive
# 0 found positive
# 8 found positive
# 4 found positive
# 4 found positive
# 5 found positive
# Doing  655 th iteration. Time : 0.00 secs. Elapsed time : 3.31 secs. Estimated :  1140.67 secs
# 0 found positive
# 2 found positive
# 7 found positive
# 0 found positive
# 5 found positive
# 7 found positive
# 7 found positive
# 1 found positive
# 1 found positive
# 5 found positive
# Doing  656 th iteration. Time : 0.01 secs. Elapsed time : 3.32 secs. Estimated :  1140.89 secs
# 7 found positive
# 1 found positive
# 0 found positive
# 0 found positive
# 8 found positive
# 0 found positive
# 4 found positive
# 3 found positive
# 0 found positive
# 6 found positive
# Doing  657 th iteration. Time : 0.02 secs. Elapsed time : 3.33 secs. Estimated :  1143.07 secs
# 5 found positive
# 3 found positive
# 3 found positive
# 5 found positive
# 1 found positive
# 8 found positive
# 4 found positive
# 1 found positive
# 8 found positive
# 4 found positive
# Doing  658 th iteration. Time : 0.00 secs. Elapsed time : 3.33 secs. Estimated :  1140.09 secs
# 4 found positive
# 0 found positive
# 5 found positive
# 8 found positive
# 1 found positive
# 0 found positive
# 8 found positive
# 4 found positive
# 0 found positive
# 2 found positive
# Doing  659 th iteration. Time : 0.01 secs. Elapsed time : 3.34 secs. Estimated :  1138.74 secs
# 5 found positive
# 7 found positive
# 2 found positive
# 4 found positive
# 3 found positive
# 1 found positive
# 1 found positive
# 6 found positive
# 5 found positive
# 4 found positive
# Doing  660 th iteration. Time : 0.00 secs. Elapsed time : 3.34 secs. Estimated :  1136.72 secs
# 6 found positive
# 2 found positive
# 0 found positive
# 8 found positive
# 2 found positive
# 8 found positive
# 8 found positive
# 3 found positive
# 0 found positive
# 4 found positive
# Doing  661 th iteration. Time : 0.00 secs. Elapsed time : 3.35 secs. Estimated :  1134.04 secs
# 1 found positive
# 8 found positive
# 4 found positive
# 5 found positive
# 6 found positive
# 5 found positive
# 3 found positive
# 8 found positive
# 8 found positive
# 0 found positive
# Doing  662 th iteration. Time : 0.00 secs. Elapsed time : 3.35 secs. Estimated :  1132.34 secs
# 6 found positive
# 1 found positive
# 5 found positive
# 3 found positive
# 4 found positive
# 0 found positive
# 1 found positive
# 7 found positive
# 5 found positive
# 2 found positive
# Doing  663 th iteration. Time : 0.00 secs. Elapsed time : 3.35 secs. Estimated :  1129.31 secs
# 7 found positive
# 3 found positive
# 3 found positive
# 8 found positive
# 4 found positive
# 2 found positive
# 8 found positive
# 6 found positive
# 6 found positive
# 2 found positive
# Doing  664 th iteration. Time : 0.00 secs. Elapsed time : 3.36 secs. Estimated :  1127.58 secs
# 3 found positive
# 5 found positive
# 2 found positive
# 5 found positive
# 0 found positive
# 1 found positive
# 0 found positive
# 1 found positive
# 0 found positive
# 6 found positive
# Doing  665 th iteration. Time : 0.00 secs. Elapsed time : 3.36 secs. Estimated :  1124.56 secs
# 1 found positive
# 6 found positive
# 7 found positive
# 5 found positive
# 0 found positive
# 5 found positive
# 8 found positive
# 1 found positive
# 2 found positive
# 2 found positive
# Doing  666 th iteration. Time : 0.02 secs. Elapsed time : 3.37 secs. Estimated :  1126.47 secs
# 5 found positive
# 1 found positive
# 2 found positive
# 7 found positive
# 6 found positive
# 5 found positive
# 6 found positive
# 5 found positive
# 8 found positive
# 5 found positive
# Doing  667 th iteration. Time : 0.02 secs. Elapsed time : 3.39 secs. Estimated :  1129.20 secs
# 4 found positive
# 6 found positive
# 5 found positive
# 5 found positive
# 5 found positive
# 3 found positive
# 6 found positive
# 4 found positive
# 3 found positive
# 4 found positive
# Doing  668 th iteration. Time : 0.02 secs. Elapsed time : 3.41 secs. Estimated :  1133.36 secs
# 6 found positive
# 5 found positive
# 3 found positive
# 2 found positive
# 0 found positive
# 0 found positive
# 7 found positive
# 7 found positive
# 2 found positive
# 1 found positive
# Doing  669 th iteration. Time : 0.00 secs. Elapsed time : 3.41 secs. Estimated :  1130.32 secs
# 1 found positive
# 5 found positive
# 0 found positive
# 5 found positive
# 3 found positive
# 8 found positive
# 6 found positive
# 5 found positive
# 0 found positive
# 0 found positive
# Doing  670 th iteration. Time : 0.02 secs. Elapsed time : 3.44 secs. Estimated :  1134.41 secs
# 4 found positive
# 1 found positive
# 2 found positive
# 5 found positive
# 7 found positive
# 3 found positive
# 5 found positive
# 1 found positive
# 4 found positive
# 6 found positive
# Doing  671 th iteration. Time : 0.00 secs. Elapsed time : 3.44 secs. Estimated :  1131.19 secs
# 1 found positive
# 6 found positive
# 6 found positive
# 0 found positive
# 1 found positive
# 1 found positive
# 3 found positive
# 5 found positive
# 7 found positive
# 4 found positive
# Doing  672 th iteration. Time : 0.00 secs. Elapsed time : 3.44 secs. Estimated :  1127.95 secs
# 6 found positive
# 7 found positive
# 2 found positive
# 8 found positive
# 8 found positive
# 5 found positive
# 6 found positive
# 1 found positive
# 0 found positive
# 1 found positive
# Doing  673 th iteration. Time : 0.00 secs. Elapsed time : 3.44 secs. Estimated :  1125.85 secs
# 5 found positive
# 6 found positive
# 5 found positive
# 3 found positive
# 8 found positive
# 4 found positive
# 6 found positive
# 3 found positive
# 5 found positive
# 8 found positive
# Doing  674 th iteration. Time : 0.00 secs. Elapsed time : 3.44 secs. Estimated :  1122.73 secs
# 1 found positive
# 5 found positive
# 1 found positive
# 8 found positive
# 8 found positive
# 5 found positive
# 2 found positive
# 4 found positive
# 3 found positive
# 2 found positive
# Doing  675 th iteration. Time : 0.01 secs. Elapsed time : 3.45 secs. Estimated :  1121.35 secs
# 7 found positive
# 1 found positive
# 5 found positive
# 0 found positive
# 7 found positive
# 2 found positive
# 0 found positive
# 5 found positive
# 0 found positive
# 1 found positive
# Doing  676 th iteration. Time : 0.00 secs. Elapsed time : 3.45 secs. Estimated :  1118.23 secs
# 5 found positive
# 0 found positive
# 5 found positive
# 0 found positive
# 1 found positive
# 4 found positive
# 6 found positive
# 1 found positive
# 1 found positive
# 6 found positive
# Doing  677 th iteration. Time : 0.00 secs. Elapsed time : 3.45 secs. Estimated :  1115.08 secs
# 6 found positive
# 7 found positive
# 7 found positive
# 5 found positive
# 3 found positive
# 4 found positive
# 1 found positive
# 6 found positive
# 2 found positive
# 3 found positive
# Doing  678 th iteration. Time : 0.02 secs. Elapsed time : 3.47 secs. Estimated :  1117.15 secs
# 4 found positive
# 1 found positive
# 6 found positive
# 7 found positive
# 4 found positive
# 0 found positive
# 8 found positive
# 8 found positive
# 5 found positive
# 6 found positive
# Doing  679 th iteration. Time : 0.01 secs. Elapsed time : 3.48 secs. Estimated :  1115.65 secs
# 1 found positive
# 0 found positive
# 8 found positive
# 3 found positive
# 7 found positive
# 2 found positive
# 8 found positive
# 1 found positive
# 3 found positive
# 6 found positive
# Doing  680 th iteration. Time : 0.01 secs. Elapsed time : 3.49 secs. Estimated :  1115.85 secs
# 6 found positive
# 7 found positive
# 4 found positive
# 6 found positive
# 1 found positive
# 7 found positive
# 7 found positive
# 1 found positive
# 7 found positive
# 3 found positive
# Doing  681 th iteration. Time : 0.00 secs. Elapsed time : 3.49 secs. Estimated :  1112.67 secs
# 3 found positive
# 5 found positive
# 2 found positive
# 7 found positive
# 4 found positive
# 6 found positive
# 7 found positive
# 4 found positive
# 5 found positive
# 5 found positive
# Doing  682 th iteration. Time : 0.00 secs. Elapsed time : 3.49 secs. Estimated :  1109.48 secs
# 3 found positive
# 5 found positive
# 6 found positive
# 2 found positive
# 1 found positive
# 0 found positive
# 2 found positive
# 7 found positive
# 8 found positive
# 5 found positive
# Doing  683 th iteration. Time : 0.01 secs. Elapsed time : 3.50 secs. Estimated :  1108.03 secs
# 5 found positive
# 7 found positive
# 8 found positive
# 8 found positive
# 1 found positive
# 0 found positive
# 4 found positive
# 7 found positive
# 4 found positive
# 5 found positive
# Doing  684 th iteration. Time : 0.00 secs. Elapsed time : 3.50 secs. Estimated :  1104.88 secs
# 7 found positive
# 0 found positive
# 3 found positive
# 7 found positive
# 2 found positive
# 0 found positive
# 0 found positive
# 6 found positive
# 4 found positive
# 5 found positive
# Doing  685 th iteration. Time : 0.00 secs. Elapsed time : 3.50 secs. Estimated :  1101.69 secs
# 0 found positive
# 4 found positive
# 1 found positive
# 8 found positive
# 3 found positive
# 0 found positive
# 0 found positive
# 0 found positive
# 7 found positive
# 2 found positive
# Doing  686 th iteration. Time : 0.00 secs. Elapsed time : 3.50 secs. Estimated :  1099.16 secs
# 3 found positive
# 8 found positive
# 5 found positive
# 2 found positive
# 8 found positive
# 7 found positive
# 5 found positive
# 2 found positive
# 3 found positive
# 1 found positive
# Doing  687 th iteration. Time : 0.01 secs. Elapsed time : 3.51 secs. Estimated :  1097.49 secs
# 8 found positive
# 6 found positive
# 3 found positive
# 7 found positive
# 6 found positive
# 0 found positive
# 6 found positive
# 2 found positive
# 4 found positive
# 5 found positive
# Doing  688 th iteration. Time : 0.00 secs. Elapsed time : 3.51 secs. Estimated :  1094.36 secs
# 7 found positive
# 4 found positive
# 1 found positive
# 6 found positive
# 6 found positive
# 4 found positive
# 5 found positive
# 6 found positive
# 8 found positive
# 3 found positive
# Doing  689 th iteration. Time : 0.00 secs. Elapsed time : 3.51 secs. Estimated :  1091.22 secs
# 3 found positive
# 1 found positive
# 3 found positive
# 5 found positive
# 1 found positive
# 7 found positive
# 0 found positive
# 5 found positive
# 0 found positive
# 2 found positive
# Doing  690 th iteration. Time : 0.00 secs. Elapsed time : 3.51 secs. Estimated :  1088.05 secs
# 5 found positive
# 7 found positive
# 2 found positive
# 7 found positive
# 0 found positive
# 0 found positive
# 0 found positive
# 8 found positive
# 1 found positive
# 8 found positive
# Doing  691 th iteration. Time : 0.00 secs. Elapsed time : 3.51 secs. Estimated :  1084.87 secs
# 1 found positive
# 3 found positive
# 8 found positive
# 8 found positive
# 3 found positive
# 6 found positive
# 4 found positive
# 0 found positive
# 2 found positive
# 2 found positive
# Doing  692 th iteration. Time : 0.00 secs. Elapsed time : 3.51 secs. Estimated :  1081.68 secs
# 8 found positive
# 2 found positive
# 7 found positive
# 7 found positive
# 2 found positive
# 2 found positive
# 7 found positive
# 7 found positive
# 4 found positive
# 7 found positive
# Doing  693 th iteration. Time : 0.00 secs. Elapsed time : 3.51 secs. Estimated :  1078.46 secs
# 8 found positive
# 8 found positive
# 5 found positive
# 4 found positive
# 4 found positive
# 2 found positive
# 2 found positive
# 6 found positive
# 7 found positive
# 5 found positive
# Doing  694 th iteration. Time : 0.00 secs. Elapsed time : 3.51 secs. Estimated :  1075.27 secs
# 3 found positive
# 3 found positive
# 2 found positive
# 6 found positive
# 6 found positive
# 0 found positive
# 7 found positive
# 1 found positive
# 5 found positive
# 8 found positive
# Doing  695 th iteration. Time : 0.00 secs. Elapsed time : 3.52 secs. Estimated :  1072.10 secs
# 4 found positive
# 2 found positive
# 3 found positive
# 7 found positive
# 4 found positive
# 2 found positive
# 4 found positive
# 4 found positive
# 5 found positive
# 6 found positive
# Doing  696 th iteration. Time : 0.00 secs. Elapsed time : 3.52 secs. Estimated :  1068.88 secs
# 3 found positive
# 2 found positive
# 3 found positive
# 4 found positive
# 3 found positive
# 8 found positive
# 7 found positive
# 8 found positive
# 5 found positive
# 8 found positive
# Doing  697 th iteration. Time : 0.00 secs. Elapsed time : 3.52 secs. Estimated :  1065.65 secs
# 3 found positive
# 4 found positive
# 3 found positive
# 7 found positive
# 7 found positive
# 4 found positive
# 1 found positive
# 8 found positive
# 6 found positive
# 0 found positive
# Doing  698 th iteration. Time : 0.00 secs. Elapsed time : 3.52 secs. Estimated :  1062.43 secs
# 4 found positive
# 4 found positive
# 3 found positive
# 8 found positive
# 7 found positive
# 2 found positive
# 4 found positive
# 8 found positive
# 0 found positive
# 0 found positive
# Doing  699 th iteration. Time : 0.01 secs. Elapsed time : 3.53 secs. Estimated :  1061.11 secs
# 1 found positive
# 5 found positive
# 6 found positive
# 3 found positive
# 2 found positive
# 3 found positive
# 5 found positive
# 8 found positive
# 6 found positive
# 1 found positive
# Doing  700 th iteration. Time : 0.00 secs. Elapsed time : 3.53 secs. Estimated :  1057.90 secs
# 3 found positive
# 1 found positive
# 8 found positive
# 1 found positive
# 5 found positive
# 4 found positive
# 6 found positive
# 8 found positive
# 3 found positive
# 8 found positive
# Doing  701 th iteration. Time : 0.00 secs. Elapsed time : 3.53 secs. Estimated :  1055.56 secs
# 2 found positive
# 1 found positive
# 6 found positive
# 3 found positive
# 2 found positive
# 3 found positive
# 2 found positive
# 0 found positive
# 7 found positive
# 1 found positive
# Doing  702 th iteration. Time : 0.00 secs. Elapsed time : 3.53 secs. Estimated :  1052.31 secs
# 0 found positive
# 6 found positive
# 1 found positive
# 5 found positive
# 3 found positive
# 2 found positive
# 7 found positive
# 6 found positive
# 6 found positive
# 6 found positive
# Doing  703 th iteration. Time : 0.00 secs. Elapsed time : 3.53 secs. Estimated :  1049.79 secs
# 2 found positive
# 5 found positive
# 4 found positive
# 5 found positive
# 6 found positive
# 3 found positive
# 7 found positive
# 4 found positive
# 7 found positive
# 2 found positive
# Doing  704 th iteration. Time : 0.00 secs. Elapsed time : 3.54 secs. Estimated :  1047.32 secs
# 8 found positive
# 3 found positive
# 2 found positive
# 7 found positive
# 7 found positive
# 6 found positive
# 6 found positive
# 2 found positive
# 3 found positive
# 7 found positive
# Doing  705 th iteration. Time : 0.04 secs. Elapsed time : 3.58 secs. Estimated :  1056.02 secs
# 4 found positive
# 4 found positive
# 5 found positive
# 6 found positive
# 7 found positive
# 7 found positive
# 6 found positive
# 7 found positive
# 3 found positive
# 1 found positive
# Doing  706 th iteration. Time : 0.00 secs. Elapsed time : 3.58 secs. Estimated :  1052.74 secs
# 7 found positive
# 0 found positive
# 6 found positive
# 2 found positive
# 2 found positive
# 8 found positive
# 8 found positive
# 7 found positive
# 1 found positive
# 1 found positive
# Doing  707 th iteration. Time : 0.00 secs. Elapsed time : 3.58 secs. Estimated :  1050.03 secs
# 7 found positive
# 3 found positive
# 8 found positive
# 5 found positive
# 3 found positive
# 0 found positive
# 0 found positive
# 8 found positive
# 8 found positive
# 7 found positive
# Doing  708 th iteration. Time : 0.00 secs. Elapsed time : 3.58 secs. Estimated :  1046.72 secs
# 8 found positive
# 4 found positive
# 8 found positive
# 6 found positive
# 1 found positive
# 0 found positive
# 6 found positive
# 5 found positive
# 8 found positive
# 1 found positive
# Doing  709 th iteration. Time : 0.00 secs. Elapsed time : 3.59 secs. Estimated :  1043.40 secs
# 0 found positive
# 0 found positive
# 4 found positive
# 8 found positive
# 8 found positive
# 4 found positive
# 2 found positive
# 2 found positive
# 6 found positive
# 6 found positive
# Doing  710 th iteration. Time : 0.00 secs. Elapsed time : 3.59 secs. Estimated :  1040.07 secs
# 4 found positive
# 3 found positive
# 6 found positive
# 5 found positive
# 1 found positive
# 7 found positive
# 5 found positive
# 4 found positive
# 4 found positive
# 1 found positive
# Doing  711 th iteration. Time : 0.00 secs. Elapsed time : 3.59 secs. Estimated :  1036.76 secs
# 6 found positive
# 7 found positive
# 3 found positive
# 2 found positive
# 7 found positive
# 4 found positive
# 4 found positive
# 5 found positive
# 5 found positive
# 8 found positive
# Doing  712 th iteration. Time : 0.00 secs. Elapsed time : 3.59 secs. Estimated :  1033.47 secs
# 0 found positive
# 5 found positive
# 2 found positive
# 0 found positive
# 6 found positive
# 6 found positive
# 1 found positive
# 0 found positive
# 7 found positive
# 6 found positive
# Doing  713 th iteration. Time : 0.00 secs. Elapsed time : 3.59 secs. Estimated :  1030.14 secs
# 2 found positive
# 2 found positive
# 4 found positive
# 1 found positive
# 7 found positive
# 3 found positive
# 4 found positive
# 8 found positive
# 7 found positive
# 5 found positive
# Doing  714 th iteration. Time : 0.01 secs. Elapsed time : 3.60 secs. Estimated :  1029.12 secs
# 1 found positive
# 6 found positive
# 4 found positive
# 7 found positive
# 3 found positive
# 8 found positive
# 1 found positive
# 4 found positive
# 4 found positive
# 0 found positive
# Doing  715 th iteration. Time : 0.00 secs. Elapsed time : 3.60 secs. Estimated :  1026.61 secs
# 3 found positive
# 4 found positive
# 0 found positive
# 5 found positive
# 5 found positive
# 3 found positive
# 0 found positive
# 0 found positive
# 0 found positive
# 1 found positive
# Doing  716 th iteration. Time : 0.00 secs. Elapsed time : 3.60 secs. Estimated :  1023.29 secs
# 6 found positive
# 7 found positive
# 4 found positive
# 3 found positive
# 7 found positive
# 4 found positive
# 2 found positive
# 0 found positive
# 1 found positive
# 5 found positive
# Doing  717 th iteration. Time : 0.00 secs. Elapsed time : 3.60 secs. Estimated :  1019.94 secs
# 3 found positive
# 0 found positive
# 6 found positive
# 5 found positive
# 4 found positive
# 7 found positive
# 2 found positive
# 3 found positive
# 5 found positive
# 6 found positive
# Doing  718 th iteration. Time : 0.01 secs. Elapsed time : 3.61 secs. Estimated :  1017.98 secs
# 6 found positive
# 4 found positive
# 0 found positive
# 4 found positive
# 6 found positive
# 1 found positive
# 8 found positive
# 8 found positive
# 4 found positive
# 3 found positive
# Doing  719 th iteration. Time : 0.01 secs. Elapsed time : 3.62 secs. Estimated :  1016.07 secs
# 8 found positive
# 8 found positive
# 7 found positive
# 3 found positive
# 2 found positive
# 4 found positive
# 1 found positive
# 7 found positive
# 4 found positive
# 3 found positive
# Doing  720 th iteration. Time : 0.01 secs. Elapsed time : 3.62 secs. Estimated :  1014.26 secs
# 8 found positive
# 1 found positive
# 8 found positive
# 4 found positive
# 8 found positive
# 4 found positive
# 1 found positive
# 1 found positive
# 7 found positive
# 7 found positive
# Doing  721 th iteration. Time : 0.00 secs. Elapsed time : 3.62 secs. Estimated :  1010.89 secs
# 0 found positive
# 0 found positive
# 7 found positive
# 5 found positive
# 1 found positive
# 3 found positive
# 6 found positive
# 2 found positive
# 2 found positive
# 1 found positive
# Doing  722 th iteration. Time : 0.07 secs. Elapsed time : 3.69 secs. Estimated :  1025.59 secs
# 8 found positive
# 3 found positive
# 2 found positive
# 1 found positive
# 4 found positive
# 1 found positive
# 3 found positive
# 2 found positive
# 4 found positive
# 3 found positive
# Doing  723 th iteration. Time : 0.00 secs. Elapsed time : 3.69 secs. Estimated :  1022.24 secs
# 5 found positive
# 0 found positive
# 7 found positive
# 0 found positive
# 5 found positive
# 4 found positive
# 2 found positive
# 1 found positive
# 2 found positive
# 8 found positive
# Doing  724 th iteration. Time : 0.01 secs. Elapsed time : 3.70 secs. Estimated :  1021.32 secs
# 4 found positive
# 0 found positive
# 7 found positive
# 1 found positive
# 3 found positive
# 2 found positive
# 3 found positive
# 0 found positive
# 8 found positive
# 0 found positive
# Doing  725 th iteration. Time : 0.00 secs. Elapsed time : 3.70 secs. Estimated :  1018.06 secs
# 7 found positive
# 1 found positive
# 4 found positive
# 2 found positive
# ...
# 5 found positive
# 5 found positive
# 2 found positive
# 7 found positive
# 4 found positive
# Doing  939 th iteration. Time : 0.00 secs. Elapsed time : 4.63 secs. Estimated :  282.60 secs
# 2 found positive
# 1 found positive
# 7 found positive
# 7 found positive
# 2 found positive
# 3 found positive
# 8 found positive
# 0 found positive
# 1 found positive
# 7 found positive
# Doing  940 th iteration. Time : 0.01 secs. Elapsed time : 4.64 secs. Estimated :  278.41 secs
# 0 found positive
# 0 found positive
# 8 found positive
# 5 found positive
# 1 found positive
# 5 found positive
# 7 found positive
# 0 found positive
# 7 found positive
# 8 found positive
# Doing  941 th iteration. Time : 0.00 secs. Elapsed time : 4.64 secs. Estimated :  273.83 secs
# 8 found positive
# 2 found positive
# 7 found positive
# 3 found positive
# 6 found positive
# 6 found positive
# 6 found positive
# 5 found positive
# 6 found positive
# 6 found positive
# Doing  942 th iteration. Time : 0.00 secs. Elapsed time : 4.64 secs. Estimated :  269.25 secs
# 1 found positive
# 6 found positive
# 1 found positive
# 6 found positive
# 8 found positive
# 1 found positive
# 6 found positive
# 5 found positive
# 3 found positive
# 6 found positive
# Doing  943 th iteration. Time : 0.01 secs. Elapsed time : 4.66 secs. Estimated :  265.39 secs
# 1 found positive
# 4 found positive
# 2 found positive
# 6 found positive
# 2 found positive
# 2 found positive
# 8 found positive
# 7 found positive
# 6 found positive
# 0 found positive
# Doing  944 th iteration. Time : 0.01 secs. Elapsed time : 4.66 secs. Estimated :  261.14 secs
# 5 found positive
# 2 found positive
# 6 found positive
# 0 found positive
# 0 found positive
# 7 found positive
# 7 found positive
# 3 found positive
# 8 found positive
# 6 found positive
# Doing  945 th iteration. Time : 0.00 secs. Elapsed time : 4.66 secs. Estimated :  256.54 secs
# 0 found positive
# 5 found positive
# 2 found positive
# 7 found positive
# 4 found positive
# 7 found positive
# 8 found positive
# 7 found positive
# 5 found positive
# 2 found positive
# Doing  946 th iteration. Time : 0.02 secs. Elapsed time : 4.69 secs. Estimated :  253.18 secs
# 4 found positive
# 3 found positive
# 8 found positive
# 3 found positive
# 6 found positive
# 5 found positive
# 5 found positive
# 1 found positive
# 2 found positive
# 1 found positive
# Doing  947 th iteration. Time : 0.00 secs. Elapsed time : 4.69 secs. Estimated :  248.75 secs
# 3 found positive
# 6 found positive
# 4 found positive
# 4 found positive
# 7 found positive
# 5 found positive
# 6 found positive
# 1 found positive
# 0 found positive
# 8 found positive
# Doing  948 th iteration. Time : 0.01 secs. Elapsed time : 4.70 secs. Estimated :  244.37 secs
# 7 found positive
# 8 found positive
# 1 found positive
# 6 found positive
# 2 found positive
# 4 found positive
# 2 found positive
# 0 found positive
# 1 found positive
# 6 found positive
# Doing  949 th iteration. Time : 0.00 secs. Elapsed time : 4.70 secs. Estimated :  239.73 secs
# 8 found positive
# 4 found positive
# 3 found positive
# 6 found positive
# 2 found positive
# 5 found positive
# 3 found positive
# 0 found positive
# 6 found positive
# 0 found positive
# Doing  950 th iteration. Time : 0.00 secs. Elapsed time : 4.70 secs. Estimated :  235.13 secs
# 2 found positive
# 8 found positive
# 3 found positive
# 2 found positive
# 5 found positive
# 6 found positive
# 8 found positive
# 4 found positive
# 4 found positive
# 6 found positive
# Doing  951 th iteration. Time : 0.00 secs. Elapsed time : 4.70 secs. Estimated :  230.49 secs
# 5 found positive
# 5 found positive
# 8 found positive
# 8 found positive
# 8 found positive
# 4 found positive
# 0 found positive
# 3 found positive
# 2 found positive
# 1 found positive
# Doing  952 th iteration. Time : 0.00 secs. Elapsed time : 4.71 secs. Estimated :  225.86 secs
# 8 found positive
# 7 found positive
# 1 found positive
# 3 found positive
# 3 found positive
# 0 found positive
# 8 found positive
# 1 found positive
# 5 found positive
# 5 found positive
# Doing  953 th iteration. Time : 0.00 secs. Elapsed time : 4.71 secs. Estimated :  221.21 secs
# 7 found positive
# 5 found positive
# 4 found positive
# 5 found positive
# 3 found positive
# 1 found positive
# 6 found positive
# 6 found positive
# 5 found positive
# 6 found positive
# Doing  954 th iteration. Time : 0.00 secs. Elapsed time : 4.71 secs. Estimated :  216.56 secs
# 0 found positive
# 8 found positive
# 5 found positive
# 8 found positive
# 8 found positive
# 7 found positive
# 6 found positive
# 5 found positive
# 8 found positive
# 3 found positive
# Doing  955 th iteration. Time : 0.00 secs. Elapsed time : 4.71 secs. Estimated :  211.90 secs
# 8 found positive
# 3 found positive
# 4 found positive
# 0 found positive
# 0 found positive
# 0 found positive
# 8 found positive
# 1 found positive
# 3 found positive
# 5 found positive
# Doing  956 th iteration. Time : 0.01 secs. Elapsed time : 4.72 secs. Estimated :  207.61 secs
# 2 found positive
# 2 found positive
# 1 found positive
# 5 found positive
# 0 found positive
# 4 found positive
# 0 found positive
# 1 found positive
# 0 found positive
# 6 found positive
# Doing  957 th iteration. Time : 0.00 secs. Elapsed time : 4.72 secs. Estimated :  202.94 secs
# 6 found positive
# 5 found positive
# 5 found positive
# 3 found positive
# 0 found positive
# 7 found positive
# 5 found positive
# 5 found positive
# 4 found positive
# 0 found positive
# Doing  958 th iteration. Time : 0.00 secs. Elapsed time : 4.72 secs. Estimated :  198.30 secs
# 5 found positive
# 2 found positive
# 1 found positive
# 7 found positive
# 1 found positive
# 7 found positive
# 1 found positive
# 0 found positive
# 8 found positive
# 4 found positive
# Doing  959 th iteration. Time : 0.00 secs. Elapsed time : 4.72 secs. Estimated :  193.62 secs
# 5 found positive
# 5 found positive
# 8 found positive
# 0 found positive
# 5 found positive
# 5 found positive
# 0 found positive
# 5 found positive
# 1 found positive
# 1 found positive
# Doing  960 th iteration. Time : 0.00 secs. Elapsed time : 4.72 secs. Estimated :  189.00 secs
# 0 found positive
# 0 found positive
# 4 found positive
# 4 found positive
# 7 found positive
# 5 found positive
# 8 found positive
# 0 found positive
# 5 found positive
# 8 found positive
# Doing  961 th iteration. Time : 0.00 secs. Elapsed time : 4.73 secs. Estimated :  184.32 secs
# 7 found positive
# 6 found positive
# 7 found positive
# 8 found positive
# 2 found positive
# 0 found positive
# 6 found positive
# 6 found positive
# 1 found positive
# 0 found positive
# Doing  962 th iteration. Time : 0.00 secs. Elapsed time : 4.73 secs. Estimated :  179.63 secs
# 5 found positive
# 0 found positive
# 5 found positive
# 5 found positive
# 5 found positive
# 6 found positive
# 3 found positive
# 5 found positive
# 1 found positive
# 2 found positive
# Doing  963 th iteration. Time : 0.04 secs. Elapsed time : 4.77 secs. Estimated :  176.54 secs
# 2 found positive
# 6 found positive
# 0 found positive
# 8 found positive
# 7 found positive
# 4 found positive
# 0 found positive
# 2 found positive
# 4 found positive
# 0 found positive
# Doing  964 th iteration. Time : 0.01 secs. Elapsed time : 4.78 secs. Estimated :  172.07 secs
# 0 found positive
# 6 found positive
# 8 found positive
# 5 found positive
# 0 found positive
# 7 found positive
# 3 found positive
# 4 found positive
# 3 found positive
# 0 found positive
# Doing  965 th iteration. Time : 0.00 secs. Elapsed time : 4.78 secs. Estimated :  167.33 secs
# 0 found positive
# 8 found positive
# 0 found positive
# 4 found positive
# 7 found positive
# 7 found positive
# 0 found positive
# 3 found positive
# 8 found positive
# 6 found positive
# Doing  966 th iteration. Time : 0.00 secs. Elapsed time : 4.78 secs. Estimated :  162.57 secs
# 0 found positive
# 4 found positive
# 4 found positive
# 1 found positive
# 4 found positive
# 4 found positive
# 6 found positive
# 0 found positive
# 2 found positive
# 7 found positive
# Doing  967 th iteration. Time : 0.01 secs. Elapsed time : 4.79 secs. Estimated :  158.06 secs
# 8 found positive
# 7 found positive
# 6 found positive
# 7 found positive
# 0 found positive
# 8 found positive
# 2 found positive
# 6 found positive
# 1 found positive
# 3 found positive
# Doing  968 th iteration. Time : 0.01 secs. Elapsed time : 4.80 secs. Estimated :  153.55 secs
# 7 found positive
# 8 found positive
# 4 found positive
# 7 found positive
# 6 found positive
# 8 found positive
# 8 found positive
# 7 found positive
# 7 found positive
# 1 found positive
# Doing  969 th iteration. Time : 0.00 secs. Elapsed time : 4.80 secs. Estimated :  148.78 secs
# 2 found positive
# 2 found positive
# 8 found positive
# 6 found positive
# 4 found positive
# 4 found positive
# 5 found positive
# 7 found positive
# 4 found positive
# 0 found positive
# Doing  970 th iteration. Time : 0.00 secs. Elapsed time : 4.80 secs. Estimated :  144.02 secs
# 8 found positive
# 7 found positive
# 4 found positive
# 5 found positive
# 7 found positive
# 2 found positive
# 7 found positive
# 7 found positive
# 6 found positive
# 2 found positive
# Doing  971 th iteration. Time : 0.02 secs. Elapsed time : 4.82 secs. Estimated :  139.87 secs
# 6 found positive
# 4 found positive
# 7 found positive
# 8 found positive
# 0 found positive
# 2 found positive
# 7 found positive
# 7 found positive
# 8 found positive
# 3 found positive
# Doing  972 th iteration. Time : 0.00 secs. Elapsed time : 4.82 secs. Estimated :  135.07 secs
# 0 found positive
# 3 found positive
# 2 found positive
# 7 found positive
# 7 found positive
# 3 found positive
# 0 found positive
# 7 found positive
# 7 found positive
# 7 found positive
# Doing  973 th iteration. Time : 0.00 secs. Elapsed time : 4.83 secs. Estimated :  130.34 secs
# 6 found positive
# 6 found positive
# 5 found positive
# 5 found positive
# 3 found positive
# 4 found positive
# 6 found positive
# 6 found positive
# 1 found positive
# 6 found positive
# Doing  974 th iteration. Time : 0.00 secs. Elapsed time : 4.83 secs. Estimated :  125.64 secs
# 2 found positive
# 5 found positive
# 8 found positive
# 7 found positive
# 7 found positive
# 1 found positive
# 1 found positive
# 3 found positive
# 4 found positive
# 2 found positive
# Doing  975 th iteration. Time : 0.00 secs. Elapsed time : 4.83 secs. Estimated :  120.83 secs
# 8 found positive
# 2 found positive
# 5 found positive
# 0 found positive
# 2 found positive
# 5 found positive
# 3 found positive
# 5 found positive
# 5 found positive
# 4 found positive
# Doing  976 th iteration. Time : 0.00 secs. Elapsed time : 4.83 secs. Estimated :  116.02 secs
# 5 found positive
# 1 found positive
# 6 found positive
# 5 found positive
# 5 found positive
# 1 found positive
# 3 found positive
# 6 found positive
# 0 found positive
# 5 found positive
# Doing  977 th iteration. Time : 0.00 secs. Elapsed time : 4.84 secs. Estimated :  111.29 secs
# 5 found positive
# 5 found positive
# 5 found positive
# 4 found positive
# 6 found positive
# 6 found positive
# 5 found positive
# 3 found positive
# 4 found positive
# 3 found positive
# Doing  978 th iteration. Time : 0.00 secs. Elapsed time : 4.84 secs. Estimated :  106.47 secs
# 2 found positive
# 5 found positive
# 8 found positive
# 7 found positive
# 7 found positive
# 8 found positive
# 3 found positive
# 2 found positive
# 2 found positive
# 8 found positive
# Doing  979 th iteration. Time : 0.00 secs. Elapsed time : 4.84 secs. Estimated :  101.65 secs
# 8 found positive
# 8 found positive
# 3 found positive
# 2 found positive
# 0 found positive
# 2 found positive
# 7 found positive
# 3 found positive
# 4 found positive
# 5 found positive
# Doing  980 th iteration. Time : 0.00 secs. Elapsed time : 4.84 secs. Estimated :  96.85 secs
# 0 found positive
# 6 found positive
# 6 found positive
# 8 found positive
# 0 found positive
# 1 found positive
# 3 found positive
# 2 found positive
# 6 found positive
# 0 found positive
# Doing  981 th iteration. Time : 0.00 secs. Elapsed time : 4.84 secs. Estimated :  92.03 secs
# 5 found positive
# 1 found positive
# 7 found positive
# 5 found positive
# 6 found positive
# 8 found positive
# 0 found positive
# 1 found positive
# 6 found positive
# 1 found positive
# Doing  982 th iteration. Time : 0.00 secs. Elapsed time : 4.84 secs. Estimated :  87.21 secs
# 0 found positive
# 6 found positive
# 2 found positive
# 0 found positive
# 0 found positive
# 7 found positive
# 6 found positive
# 4 found positive
# 0 found positive
# 1 found positive
# Doing  983 th iteration. Time : 0.00 secs. Elapsed time : 4.85 secs. Estimated :  82.38 secs
# 0 found positive
# 6 found positive
# 5 found positive
# 5 found positive
# 8 found positive
# 6 found positive
# 6 found positive
# 8 found positive
# 1 found positive
# 7 found positive
# Doing  984 th iteration. Time : 0.01 secs. Elapsed time : 4.85 secs. Estimated :  77.67 secs
# 5 found positive
# 2 found positive
# 0 found positive
# 4 found positive
# 0 found positive
# 5 found positive
# 1 found positive
# 1 found positive
# 1 found positive
# 1 found positive
# Doing  985 th iteration. Time : 0.00 secs. Elapsed time : 4.86 secs. Estimated :  72.83 secs
# 7 found positive
# 6 found positive
# 1 found positive
# 8 found positive
# 2 found positive
# 0 found positive
# 3 found positive
# 4 found positive
# 1 found positive
# 7 found positive
# Doing  986 th iteration. Time : 0.00 secs. Elapsed time : 4.86 secs. Estimated :  67.99 secs
# 7 found positive
# 0 found positive
# 7 found positive
# 4 found positive
# 8 found positive
# 4 found positive
# 7 found positive
# 3 found positive
# 1 found positive
# 7 found positive
# Doing  987 th iteration. Time : 0.00 secs. Elapsed time : 4.86 secs. Estimated :  63.15 secs
# 4 found positive
# 1 found positive
# 2 found positive
# 8 found positive
# 8 found positive
# 5 found positive
# 7 found positive
# 2 found positive
# 2 found positive
# 2 found positive
# Doing  988 th iteration. Time : 0.00 secs. Elapsed time : 4.86 secs. Estimated :  58.30 secs
# 7 found positive
# 4 found positive
# 3 found positive
# 8 found positive
# 5 found positive
# 4 found positive
# 7 found positive
# 6 found positive
# 0 found positive
# 0 found positive
# Doing  989 th iteration. Time : 0.00 secs. Elapsed time : 4.86 secs. Estimated :  53.46 secs
# 3 found positive
# 7 found positive
# 6 found positive
# 5 found positive
# 3 found positive
# 0 found positive
# 5 found positive
# 0 found positive
# 4 found positive
# 8 found positive
# Doing  990 th iteration. Time : 0.00 secs. Elapsed time : 4.86 secs. Estimated :  48.64 secs
# 6 found positive
# 2 found positive
# 5 found positive
# 1 found positive
# 5 found positive
# 8 found positive
# 4 found positive
# 2 found positive
# 7 found positive
# 3 found positive
# Doing  991 th iteration. Time : 0.00 secs. Elapsed time : 4.87 secs. Estimated :  43.80 secs
# 4 found positive
# 1 found positive
# 8 found positive
# 6 found positive
# 4 found positive
# 1 found positive
# 8 found positive
# 5 found positive
# 5 found positive
# 4 found positive
# Doing  992 th iteration. Time : 0.00 secs. Elapsed time : 4.87 secs. Estimated :  38.94 secs
# 7 found positive
# 4 found positive
# 2 found positive
# 6 found positive
# 6 found positive
# 4 found positive
# 5 found positive
# 0 found positive
# 0 found positive
# 4 found positive
# Doing  993 th iteration. Time : 0.01 secs. Elapsed time : 4.87 secs. Estimated :  34.11 secs
# 7 found positive
# 0 found positive
# 6 found positive
# 4 found positive
# 1 found positive
# 5 found positive
# 4 found positive
# 3 found positive
# 2 found positive
# 3 found positive
# Doing  994 th iteration. Time : 0.00 secs. Elapsed time : 4.87 secs. Estimated :  29.24 secs
# 0 found positive
# 1 found positive
# 5 found positive
# 8 found positive
# 5 found positive
# 4 found positive
# 0 found positive
# 2 found positive
# 5 found positive
# 2 found positive
# Doing  995 th iteration. Time : 0.01 secs. Elapsed time : 4.88 secs. Estimated :  24.40 secs
# 5 found positive
# 6 found positive
# 0 found positive
# 8 found positive
# 0 found positive
# 5 found positive
# 1 found positive
# 1 found positive
# 8 found positive
# 4 found positive
# Doing  996 th iteration. Time : 0.00 secs. Elapsed time : 4.88 secs. Estimated :  19.53 secs
# 0 found positive
# 3 found positive
# 6 found positive
# 0 found positive
# 4 found positive
# 0 found positive
# 2 found positive
# 8 found positive
# 2 found positive
# 2 found positive
# Doing  997 th iteration. Time : 0.01 secs. Elapsed time : 4.90 secs. Estimated :  14.69 secs
# 2 found positive
# 5 found positive
# 2 found positive
# 0 found positive
# 5 found positive
# 2 found positive
# 4 found positive
# 7 found positive
# 6 found positive
# 8 found positive
# Doing  998 th iteration. Time : 0.08 secs. Elapsed time : 4.98 secs. Estimated :  9.95 secs
# 8 found positive
# 2 found positive
# 6 found positive
# 6 found positive
# 5 found positive
# 5 found positive
# 1 found positive
# 1 found positive
# 4 found positive
# 6 found positive
# Doing  999 th iteration. Time : 0.00 secs. Elapsed time : 4.98 secs. Estimated :  4.98 secs

# %% [markdown]
# #Execute this if you want to run the simulation with sliders.

# %%
pop = widgets.IntSlider(value=5000, 
                      description='population size', 
                      max=100000, 
                      min=10000,
                      step=10000) #population_size
k = widgets.IntSlider(value=10, 
                      description='nearest neighbors', 
                      max=100, 
                      min=0,
                      step=5) #nearest neighbor
p = widgets.FloatSlider(value=0.5,
                        description='probability', 
                        max=1, 
                        min=0, 
                        step=0.1) #probability
iter = widgets.IntSlider(value=100, 
                               description='days', 
                               max=600, 
                               min=0, 
                               step=20)
tpm = widgets.IntSlider(value=1000,
                        description='test per million',
                        max=100000,
                        min=1000,
                        step=1000)
ex = widgets.IntSlider(value=50,
                       description='initial exposed',
                       max=500,
                       min=10,
                       step=10)


def simulation(pop,k,p,iter,tpm,ex):
    #Generating the small world network
    population = gen_graph(pop, k, p)

    #Exposing the population
    #li is the list of the first round of exposed population
    population,li = expose_population(ex, population)


    #Number of days the simulation need to run
    count = np.arange(iter)


    # List to contain the current data
    susp = []
    expo = []
    infe = []
    reco = []
    dead = []


    elapsed = 0
    # Running the days simulation for given number of days
    for j in range (iter):
      inter = []
      tic = time.time()
      population, sus, exp, inf, rec, ded = days(population, tpm)
      susp.append(len(sus)) #Count of suspected persons per day
      expo.append(len(exp)) #Count of exposed persons per day
      infe.append(len(inf)) #Count of infected persons per day
      reco.append(len(rec)) #Count of recovered persons per day
      dead.append(len(ded))
      toc = time.time()
      one_day = toc - tic
      elapsed += one_day
      estimated = elapsed*(iter-j)
      remaining = (iter * one_day) - (j * one_day)
      #print("Doing ",j,"th iteration. Time :","{:.2f}".format(one_day),
       #     "secs. Elapsed time :","{:.2f}".format(elapsed),"secs. Remaining : ","{:.2f}".format(remaining),"secs")
    #progress_bar(estimated,elapsed)
    
    plt.figure(figsize=(20,10))
    plt.plot(count, susp, color='b', label = "Susceptible")
    plt.plot(count, expo, color='y', label = "Exposed")
    plt.plot(count, infe, color='r', label = "Infected")
    plt.plot(count, reco, color='g', label = "Recovered")
    plt.plot(count, dead, color='k', label = "Dead")
    label = "Probability = "+str(p)+". Nearest Neigbours = "+str(k)+"."
    plt.title(label, fontdict=None, loc='center', pad=None)
    plt.legend()
    return()
ui = widgets.HBox([pop,k,p,iter,tpm,ex])
out = widgets.interactive_output(simulation, {'pop':pop,'k':k,'p':p,'iter':iter,'tpm':tpm,'ex':ex})

display(ui, out)
# Out:
# HBox(children=(IntSlider(value=10000, description='population size', max=100000, min=10000, step=10000), IntSl…
# Output()
